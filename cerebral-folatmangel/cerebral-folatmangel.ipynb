# %% [raw]
# ---
# title: "Cerebral folatmangel"
# author: "Per T.K. Flemmen"
# date: last-modified
# lang: nb
# format:
#   revealjs:
#     theme: default
#     slide-number: true
#     chalkboard: true
# ---

# %% [markdown]
# ```{css}
# .folate-slide {
#   font-size: 0.7em;
# }
#
# .folate-figure {
#   display: flex;
#   justify-content: center;
#   margin-top: 0.4em;
# }
#
# .folate-figure svg {
#   width: min(1100px, 100%);
#   height: auto;
# }
#
# .folate-base {
#   stroke: #111;
#   stroke-width: 3;
#   fill: none;
#   stroke-linecap: round;
#   stroke-linejoin: round;
# }
#
# .folate-double {
#   stroke-width: 1.8;
# }
#
# .folate-red {
#   stroke: #c81d25;
#   fill: none;
# }
#
# .folate-red-fill {
#   fill: #c81d25;
# }
#
# .folate-label {
#   font-size: 24px;
#   fill: #111;
#   font-family: "Helvetica Neue", Arial, sans-serif;
# }
#
# .folate-small {
#   font-size: 20px;
# }
#
# .folate-caption {
#   margin-top: 0.5em;
#   text-align: center;
#   font-size: 0.85em;
# }
#
# .folate-caption .fragment {
#   color: #c81d25;
# }
# ```
#
#
# ## Disposisjon
# - Hva er folat?
#   - Nomenklatur
# - Hvorfor trenger vi folat?
#   - Nevne kjente settinger: graviditet, anemi
#   - Hjernen og resten av kroppen
# - Omsetning av folat (inkl. MTHFR)
#   - Bemerke hvor metotreksat virker, f.eks.
#   - Bemerke forskjell på folat og folinat
# - Hvordan kommer folat inn i hjernen?
#
# ## Nomenklatur
# - *folsyre* ⇌ *folat*
# - *folinsyre* ⇌ *folinat*
# - *leucovorin* (amer.) = *kalsiumfolinat*
# - *folininsyre* (hist.) = *folinsyre*
#   - Fra da *folsyre* og *folinsyre* begge ble brukt om dagens *folsyre*
# - *folater* = *vitamin B₉*
#
# ## Folic acid og 5-methyl-tetrahydrofolate
#
# ::: {.folate-slide}
# <div class="folate-figure">
# <svg viewBox="0 0 1200 520" role="img" aria-label="Struktur av folic acid, med trinnvis overgang til 5-methyl-tetrahydrofolate">
#   <g>
#     <polygon class="folate-base" points="120,170 190,130 260,170 260,250 190,290 120,250" />
#     <line class="folate-base folate-double" x1="132" y1="179" x2="183" y2="149" />
#     <line class="folate-base folate-double" x1="248" y1="179" x2="248" y2="241" />
#     <line class="folate-base folate-double" x1="183" y1="271" x2="132" y2="241" />
#     <text class="folate-label" x="105" y="165">N</text>
#     <text class="folate-label" x="187" y="122">N</text>
#     <text class="folate-label" x="266" y="167">N</text>
#     <text class="folate-label" x="187" y="309">NH₂</text>
#
#     <polygon class="folate-base" points="260,170 330,150 390,190 365,260 295,270 260,250" />
#     <line class="folate-base folate-double" x1="279" y1="177" x2="323" y2="164" />
#     <line class="folate-base folate-double" x1="342" y1="160" x2="378" y2="184" />
#     <text class="folate-label" x="333" y="146">N</text>
#     <text class="folate-label" x="371" y="274">N</text>
#
#     <line class="folate-base" x1="390" y1="190" x2="460" y2="190" />
#     <text class="folate-label" x="405" y="176">CH₂</text>
#     <text class="folate-label" x="447" y="176">NH</text>
#
#     <polygon class="folate-base" points="500,170 575,130 650,170 650,250 575,290 500,250" />
#     <line class="folate-base folate-double" x1="512" y1="179" x2="563" y2="149" />
#     <line class="folate-base folate-double" x1="638" y1="179" x2="638" y2="241" />
#     <line class="folate-base folate-double" x1="563" y1="271" x2="512" y2="241" />
#     <text class="folate-label" x="566" y="122">NH₂</text>
#
#     <line class="folate-base" x1="650" y1="210" x2="735" y2="210" />
#     <text class="folate-label" x="665" y="196">C=O</text>
#     <text class="folate-label" x="700" y="196">NH</text>
#
#     <line class="folate-base" x1="735" y1="210" x2="790" y2="170" />
#     <line class="folate-base" x1="735" y1="210" x2="790" y2="250" />
#     <text class="folate-label" x="792" y="175">CH</text>
#     <text class="folate-label" x="830" y="175">COOH</text>
#     <text class="folate-label" x="792" y="258">CH₂</text>
#
#     <line class="folate-base" x1="820" y1="250" x2="900" y2="250" />
#     <text class="folate-label" x="835" y="236">CH₂</text>
#     <text class="folate-label" x="882" y="236">CH₂</text>
#
#     <line class="folate-base" x1="900" y1="250" x2="975" y2="250" />
#     <text class="folate-label" x="914" y="236">C=O</text>
#     <text class="folate-label" x="950" y="236">OH</text>
#
#     <text class="folate-label" x="330" y="360">Folic acid</text>
#     <text class="folate-label folate-small" x="290" y="392">Pteridine ring - p-aminobenzoate - glutamate</text>
#   </g>
#
#   <g class="fragment" data-fragment-index="1">
#     <line class="folate-base folate-red" x1="132" y1="179" x2="183" y2="149" />
#     <line class="folate-base folate-red" x1="248" y1="179" x2="248" y2="241" />
#     <text class="folate-label folate-red-fill" x="140" y="145">H</text>
#     <text class="folate-label folate-red-fill" x="278" y="208">H</text>
#     <text class="folate-label folate-red-fill" x="340" y="112">CH₃</text>
#     <line class="folate-base folate-red" x1="346" y1="118" x2="341" y2="136" />
#     <text class="folate-label folate-red-fill" x="285" y="92">5-methyl-tetrahydrofolate</text>
#     <text class="folate-label folate-small folate-red-fill" x="275" y="430">Rødt markerer reduksjon i pteridinringen og en metylgruppe på N5</text>
#   </g>
# </svg>
# </div>
#
# <div class="folate-caption">
# Først vises <strong>folic acid</strong>.
# <span class="fragment" data-fragment-index="1">Ved neste klikk vises <strong>5-methyl-tetrahydrofolate</strong>, der forskjellene er markert i rødt.</span>
# </div>
# :::
